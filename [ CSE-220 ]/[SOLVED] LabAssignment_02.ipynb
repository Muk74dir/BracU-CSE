# %%
                            ###LAB_Assignment_02 :

data = [[""]*10, [""]*10]
bil1 = input()
bil2 = input()
capbil1 = str()
capbil2 = str()
if len(bil1)>10 or len(bil2)> 10:
    print("INVALID")
else:
    for i in range(len(bil1)):
        data[0][i] = bil1[i]
        if(ord(bil1[i])>= 65 and ord(bil1[i])<= 90):
            capbil1 = bil1[i]
    for j in range(len(bil2)):
        data[1][j] = bil2[j]
        if(ord(bil2[j])>= 65 and ord(bil2[j])<= 90):
            capbil2 = bil2[j]

    q = False
    s1 = len(bil1)
    s2 = len(bil2)  
    start = bil1.index(capbil1)-1
    end = bil2.index(capbil2)+1

    print("Your input is valid. Press any key and then press enter to continue!!!")
    print("Top Board Charecter: ", capbil1)
    print("Top Board Start Index: ", bil1.index(capbil1))
    print("Bottom Board Charecter: ", capbil2)
    print("Bottom Board Start Index: ", bil2.index(capbil2))
    print("Press q/Q to quit")

    while q != True:
        q = input("\nPress any key and then press enter to continue!!! q/Q to quit:")
        if q == 'q' or q == 'Q':
            q = True
        else:
            start += 1
            end -= 1 

        if(start == s1):
            start = 0
        i = 0
        while i < s1:
            print(bil1[start], end='')
            start += 1
            i +=1
            if(start == s1):
                start = 0
        
        print("")

        if(end == s2):
            end = 0
        j = 0
        while j < s2:
            print(bil2[end], end='') 
            end += 1
            j +=1
            if(end == s2):
                end = 0
    
    print("\nTop Board Charecter: ", capbil1)
    print("Top Board Start Index: ", bil1.index(capbil1))
    print("Bottom Board Charecter: ", capbil2)
    print("Bottom Board Start Index: ", bil2.index(capbil2))
# Out:
# 123456R789
# 12L456789
# Your input is valid. Press any key and then press enter to continue!!!
# Top Board Charecter:  R
# Top Board Start Index:  6
# Bottom Board Charecter:  L
# Bottom Board Start Index:  2
# Press q/Q to quit
#
# Press any key and then press enter to continue!!! q/Q to quit:d
# R789123456
# L45678912
# Press any key and then press enter to continue!!! q/Q to quit:l
# 789123456R
# 2L4567891
# Press any key and then press enter to continue!!! q/Q to quit:e
# 89123456R7
# 12L456789
# Press any key and then press enter to continue!!! q/Q to quit:t
# 9123456R78
# 912L45678
# Press any key and then press enter to continue!!! q/Q to quit:r
# 123456R789
# 8912L4567
# Press any key and then press enter to continue!!! q/Q to quit:d
# 23456R7891
# 78912L456
# Press any key and then press enter to continue!!! q/Q to quit:f
# 3456R78912
# 678912L45
# Press any key and then press enter to continue!!! q/Q to quit:q
# 3456R78912
# 678912L45
# Top Board Charecter:  R
# ...
